# %%
import dask.dataframe as dd

df = dd.read_csv('missing_info_questions.csv')
df.groupby('question').sum().compute()
# Out:
# Empty DataFrame
# Columns: []
# Index: [Can a company refuse to pay my final paycheck on my last day?, Can a landlord raise rent in the middle of a lease?, Can my company legally change the terms after I agreed?, Can my company legally charge extra fees without explanation?, Can my company legally deny benefits I was promised?, Can my company legally fire me without warning?, Can my company legally force me to sign a new agreement?, Can my company legally ignore written agreements?, Can my company legally refuse to pay money they owe me?, Can my company legally retaliate after I complained?, Can my company legally terminate a contract early?, Can my company legally withhold important information?, Can my employer change my schedule without telling me in advance?, Can my employer legally change the terms after I agreed?, Can my employer legally charge extra fees without explanation?, Can my employer legally deny benefits I was promised?, Can my employer legally fire me without warning?, Can my employer legally force me to sign a new agreement?, Can my employer legally ignore written agreements?, Can my employer legally refuse to pay money they owe me?, Can my employer legally retaliate after I complained?, Can my employer legally terminate a contract early?, Can my employer legally withhold important information?, Can my landlord keep my security deposit for normal wear and tear?, Can my landlord legally change the terms after I agreed?, Can my landlord legally charge extra fees without explanation?, Can my landlord legally deny benefits I was promised?, Can my landlord legally fire me without warning?, Can my landlord legally force me to sign a new agreement?, Can my landlord legally ignore written agreements?, Can my landlord legally refuse to pay money they owe me?, Can my landlord legally retaliate after I complained?, Can my landlord legally terminate a contract early?, Can my landlord legally withhold important information?, Can my manager legally change the terms after I agreed?, Can my manager legally charge extra fees without explanation?, Can my manager legally deny benefits I was promised?, Can my manager legally fire me without warning?, Can my manager legally force me to sign a new agreement?, Can my manager legally ignore written agreements?, Can my manager legally refuse to pay money they owe me?, Can my manager legally retaliate after I complained?, Can my manager legally terminate a contract early?, Can my manager legally withhold important information?, Can my neighbor legally change the terms after I agreed?, Can my neighbor legally charge extra fees without explanation?, Can my neighbor legally deny benefits I was promised?, Can my neighbor legally fire me without warning?, Can my neighbor legally ignore written agreements?, Can my neighbor legally refuse to pay money they owe me?, Can my neighbor legally retaliate after I complained?, Can my neighbor legally terminate a contract early?, Do I have legal rights if my company change the terms after I agreed?, Do I have legal rights if my company charge extra fees without explanation?, Do I have legal rights if my company deny benefits I was promised?, Do I have legal rights if my company fire me without warning?, Do I have legal rights if my company force me to sign a new agreement?, Do I have legal rights if my company ignore written agreements?, Do I have legal rights if my company refuse to pay money they owe me?, Do I have legal rights if my company retaliate after I complained?, Do I have legal rights if my company terminate a contract early?, Do I have legal rights if my company withhold important information?, Do I have legal rights if my employer change the terms after I agreed?, Do I have legal rights if my employer charge extra fees without explanation?, Do I have legal rights if my employer deny benefits I was promised?, Do I have legal rights if my employer fire me without warning?, Do I have legal rights if my employer force me to sign a new agreement?, Do I have legal rights if ...
#
# [200 rows x 0 columns]

# %%
import pandas as pd

df = pd.read_parquet("usa_laws.parquet")

# %%
df['content'][0]
# Out:
# "Discussion Questions - Rule of Law\nSkip to main content\nAn official website of the United States government\nHere’s how you know\nHere’s how you know\nOfficial websites use .gov\nA\n.gov\nwebsite belongs to an official government\n                organization in the United States.\nSecure .gov websites use HTTPS\nA\nlock\n(\nLock\nLocked padlock icon\n) or\nhttps://\nmeans you’ve safely connected to\n                the .gov website. Share sensitive information only on official, secure websites.\nHome\nClose menu\nMain Menu\nSearch USCourts.gov\nSearch\nAbout Federal Courts\nThe U.S. Courts were created under Article III of the Constitution to administer justice fairly.\nAbout\n                        Federal\nCourts\nBack to\nMain Menu\nThe U.S. Courts were created under Article III of the Constitution to administer justice fairly.\nPopular\nCourt Website Links\nAuthorized Judgeships\nSupreme Court Landmarks\nAbout\n                        Federal\nCourts\nCourt Role and Structure\nThe judicial branch is one of the three separate and distinct branches of the federal government.\nCourt Role and Structure\nThe judicial branch is one of the three separate and distinct branches of the federal government.\nBack\nCourt\n                                                Role\n                                                and\nStructure\nAbout the U.S. Courts of Appeals\nAbout U.S. District Courts\nAbout U.S. Bankruptcy Courts\nComparing Federal & State Courts\nCourt Website Links\nFAQs: Court Information\nTypes of Cases\nU.S. Courts hear cases over which they have jurisdiction granted by the Constitution or Congress.\nTypes of Cases\nU.S. Courts hear cases over which they have jurisdiction granted by the Constitution or Congress.\nBack\nTypes\n                                                of\nCases\nAppeals\nBankruptcy Cases\nCivil Cases\nCriminal Cases\nAbout Federal Judges\nFederal judges work to ensure equal justice under the law.\nAbout Federal Judges\nFederal judges work to ensure equal justice under the law.\nBack\nAbout\n                                                Federal\nJudges\nTypes of Federal Judges\nAuthorized Judgeships\nJudicial Compensation\nJudicial Milestones\nProbation and Pretrial Services\nU.S. probation and pretrial services officers serve the federal courts and protect communities.\nProbation and Pretrial Services\nU.S. probation and pretrial services officers serve the federal courts and protect communities.\nBack\nProbation\n                                                and\n                                                Pretrial\nServices\nEvidence-Based Practices\nOfficers & Officer Assistants\nPretrial Services\nPresentence Investigations\nPost-Conviction Supervision\nData Release Regulations\nFederal Probation Journal\nFederal Probation and Pretrial Academy\nHistory\nDefender Services\nThe Constitution's Sixth Amendment guarantees an accused the right to representation by counsel.\nDefender Services\nThe Constitution's Sixth Amendment guarantees an accused the right to representation by counsel.\nBack\nDefender\nServices\nDefender Services Mission\nPublications\nCJA Panel Attorney Funds Information FY 2025\nEducational Resources\nFind realistic simulations and memorable, interactive approaches to court basics.\nEducational Resources\nFind realistic simulations and memorable, interactive approaches to court basics.\nBack\nEducational\nResources\nEducational Activities\nSupreme Court Landmarks\nAnnual Observances\nAbout Educational Outreach\nCourt Programs\nLearn about federal court programs and services to help provide fair and impartial justice.\nCourt\nPrograms\nBack to\nMain Menu\nLearn about federal court programs and services to help provide fair and impartial justice.\nPopular\nBankruptcy Basics\nFiling Without an Attorney\nSummoned for Federal Jury Service?\nCourt\nPrograms\nBankruptcy\nBankruptcy helps people who can no longer pay their debts get a fresh start by liquidating assets.\nB ...

# %%
import boto3
import pandas as pd
from io import BytesIO

s3 = boto3.client(
    "s3",
    endpoint_url="http://localhost:9000",
    aws_access_key_id="admin",
    aws_secret_access_key="admin123"
)

df = pd.DataFrame({"id": [1,2,3], "value": [10,20,30]})

out = BytesIO()
df.to_csv(out, index=False)

s3.put_object(Bucket="raw", Key="sales_data.csv", Body=out.getvalue())
# Out:
# {'ResponseMetadata': {'RequestId': '18819566930CDE31',
#   'HostId': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '0',
#    'etag': '"eb6f80934b88da4bf3d748dad85f943d"',
#    'server': 'MinIO',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-checksum-crc32': 'nvt5aA==',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'x-amz-id-2': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#    'x-amz-request-id': '18819566930CDE31',
#    'x-content-type-options': 'nosniff',
#    'x-ratelimit-limit': '1408',
#    'x-ratelimit-remaining': '1408',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Tue, 16 Dec 2025 03:46:37 GMT'},
#   'RetryAttempts': 0},
#  'ETag': '"eb6f80934b88da4bf3d748dad85f943d"',
#  'ChecksumCRC32': 'nvt5aA==',
#  'ChecksumType': 'FULL_OBJECT'}
